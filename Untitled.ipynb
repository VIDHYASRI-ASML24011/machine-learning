# %%
import joblib
import numpy as np

model = joblib.load("students_marks_model.pk1")

# %%
hours = float(input("Enter hours studied:"))
attendance = float(input("Enter attendance %:"))
sleep = float(input("Enter sleep hours:"))
prev = float(input("Enter previous exam marks:"))
# Out:
# Enter hours studied: 8
# Enter attendance %: 90
# Enter sleep hours: 8
# Enter previous exam marks: 85

# %%
data = np.array([[hours, attendance, sleep, prev]])
prediction = model.predict(data)

print("predicted final marks:", prediction[0])
# Out:
# predicted final marks: 89.64524029142682
# C:\Users\Hp\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
